# %%
import os
from crewai import LLM, Agent, Task, Crew
from crewai.tools import BaseTool
from dotenv import load_dotenv

load_dotenv()

api_key = os.getenv("OPENAI_API_KEY")

# %%
llm = LLM(model="openai/gpt-5-nano", temperature=1)

# %%
research_agent = Agent(
    role="Research Specialist",
    goal="Research interesting thing about {topic}",
    backstory="You are an expert at finding relevant and factual data",
    verbose=True,
    llm=llm
)

writer_agent = Agent(
    role="Creative Writer",
    goal="Write a short blog summary using the research",
    backstory="You are skilled at writing engaging summaries based on content",
    verbose=True,
    llm=llm)

# %%
task1 = Task(
    description="Find 3-5 recent and interesting facts about {topic}",
    expected_output="A bullet list of 3-5 facts",
    agent = research_agent,
)

task2 = Task(
    description="Write a 100 word blog post summary about {topic} using the facts from research",
    expected_output="A blog post summary",
    agent = writer_agent,
    context=[task1],
)

# %%
crew = Crew(
    agents = [research_agent, writer_agent],
    tasks = [task1, task2],
    verbose=True,
)

crew.kickoff(inputs={"topic":"The future of Electrical Vehicles"})
# Out:
# ╭─────────────────────────────────────────── 🚀 Crew Execution Started ───────────────────────────────────────────╮
# │                                                                                                                 │
# │  Crew Execution Started                                                                                         │
# │  Name: crew                                                                                                     │
# │  ID: d3c501b8-5c8c-488a-a786-deb3b3dfeb15                                                                       │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────────────── 📋 Task Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Started                                                                                                   │
# │  Name: Find 3-5 recent and interesting facts about The future of Eliectrical Vehicles                           │
# │  ID: 2a148ce4-b058-4e3b-8a5b-8ea46277d2e1                                                                       │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Research Specialist                                                                                     │
# │                                                                                                                 │
# │  Task: Find 3-5 recent and interesting facts about The future of Eliectrical Vehicles                           │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭───────────────────────────────────────────── ✅ Agent Final Answer ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Research Specialist                                                                                     │
# │                                                                                                                 │
# │  Final Answer:                                                                                                  │
# │  - Battery costs near $100 per kWh by the mid-2020s, driving price parity with many internal combustion         │
# │  vehicles and lowering total cost of ownership for most buyers. This trend is accelerating broader EV adoption  │
# │  across segments.                                                                                               │
# │                                                                                                                 │
# │  - Lithium iron phosphate (LFP) chemistries are becoming mainstream for affordable EVs due to lower cost and    │
# │  better durability, reducing reliance on nickel and cobalt. Many brands now offer LFP variants for              │
# │  standard-range models, while higher-end versions continue to use nickel-rich chemistries for longer range.     │
# │                                                                                                                 │
# │  - 800V architectures with ultra-fast charging (often 350 kW and above) are becoming common in new long-range   │
# │  EVs, enabling substantial recharges in minutes and making highway travel quicker and more convenient. This     │
# │  improves charging efficiency and reduces charging bottlenecks on major corridors.                              │
# │                                                                                                                 │
# │  - Vehicle-to-grid (V2G) and bidirectional charging pilots are expanding, allowing EVs to feed energy back to   │
# │  the grid or provide grid-balancing services during peak demand. Regulators and utilities are increasingly      │
# │  integrating these capabilities into pilots and future market designs.                                          │
# │                                                                                                                 │
# │  - Policy momentum and battery recycling/second-life use are shaping the future EV landscape: many regions      │
# │  plan ICE bans in the 2030s, incentives continue to support adoption, and new rules target recycled content     │
# │  and second-life battery storage, boosting domestic supply chains and reducing waste.                           │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭────────────────────────────────────────────── 📋 Task Completion ───────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Completed                                                                                                 │
# │  Name: Find 3-5 recent and interesting facts about The future of Eliectrical Vehicles                           │
# │  Agent: Research Specialist                                                                                     │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────────────── 📋 Task Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Started                                                                                                   │
# │  Name: Write a 100 word blog post summary about The future of Eliectrical Vehicles using the facts from         │
# │  research                                                                                                       │
# │  ID: 6bfe5425-7945-445e-91e7-f60ff8f7b84e                                                                       │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Creative Writer                                                                                         │
# │                                                                                                                 │
# │  Task: Write a 100 word blog post summary about The future of Eliectrical Vehicles using the facts from         │
# │  research                                                                                                       │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭───────────────────────────────────────────── ✅ Agent Final Answer ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Creative Writer                                                                                         │
# │                                                                                                                 │
# │  Final Answer:                                                                                                  │
# │  The future of electric vehicles is shaping up around affordability, durability, and smarter grids. Battery     │
# │  costs near $100 per kWh by the mid-2020s are driving price parity with many internal-combustion cars,          │
# │  slashing total ownership costs and accelerating cross‑segment adoption. Lithium iron phosphate chemistry is    │
# │  widening access, lowering cost and reducing nickel and cobalt reliance, with LFP variants standard on many     │
# │  mainstream models and nickel-rich packs reserved for longer-range versions. 800‑volt architectures with 350    │
# │  kW-plus charging are becoming standard, enabling rapid top‑ups on the highway and smoother long trips. V2G     │
# │  pilots and recycling/second‑life policies will strengthen grids, supply chains, and sustainability.            │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭────────────────────────────────────────────── 📋 Task Completion ───────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Completed                                                                                                 │
# │  Name: Write a 100 word blog post summary about The future of Eliectrical Vehicles using the facts from         │
# │  research                                                                                                       │
# │  Agent: Creative Writer                                                                                         │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────────────── Crew Completion ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Crew Execution Completed                                                                                       │
# │  Name: crew                                                                                                     │
# │  ID: d3c501b8-5c8c-488a-a786-deb3b3dfeb15                                                                       │
# │  Final Output: The future of electric vehicles is shaping up around affordability, durability, and smarter      │
# │  grids. Battery costs near $100 per kWh by the mid-2020s are driving price parity with many                     │
# │  internal-combustion cars, slashing total ownership costs and accelerating cross‑segment adoption. Lithium      │
# │  iron phosphate chemistry is widening access, lowering cost and reducing nickel and cobalt reliance, with LFP   │
# │  variants standard on many mainstream models and nickel-rich packs reserved for longer-range versions.          │
# │  800‑volt architectures with 350 kW-plus charging are becoming standard, enabling rapid top‑ups on the highway  │
# │  and smoother long trips. V2G pilots and recycling/second‑life policies will strengthen grids, supply chains,   │
# │  and sustainability.                                                                                            │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# CrewOutput(raw='The future of electric vehicles is shaping up around affordability, durability, and smarter grids. Battery costs near $100 per kWh by the mid-2020s are driving price parity with many internal-combustion cars, slashing total ownership costs and accelerating cross‑segment adoption. Lithium iron phosphate chemistry is widening access, lowering cost and reducing nickel and cobalt reliance, with LFP variants standard on many mainstream models and nickel-rich packs reserved for longer-range versions. 800‑volt architectures with 350 kW-plus charging are becoming standard, enabling rapid top‑ups on the highway and smoother long trips. V2G pilots and recycling/second‑life policies will strengthen grids, supply chains, and sustainability.', pydantic=None, json_dict=None, tasks_output=[TaskOutput(description='Find 3-5 recent and interesting facts about The future of Eliectrical Vehicles', name='Find 3-5 recent and interesting facts about The future of Eliectrical Vehicles', expected_output='A bullet list of 3-5 facts', summary='Find 3-5 recent and interesting facts about The future of...', raw='- Battery costs near $100 per kWh by the mid-2020s, driving price parity with many internal combustion vehicles and lowering total cost of ownership for most buyers. This trend is accelerating broader EV adoption across segments.\n\n- Lithium iron phosphate (LFP) chemistries are becoming mainstream for affordable EVs due to lower cost and better durability, reducing reliance on nickel and cobalt. Many brands now offer LFP variants for standard-range models, while higher-end versions continue to use nickel-rich chemistries for longer range.\n\n- 800V architectures with ultra-fast charging (often 350 kW and above) are becoming common in new long-range EVs, enabling substantial recharges in minutes and making highway travel quicker and more convenient. This improves charging efficiency and reduces charging bottlenecks on major corridors.\n\n- Vehicle-to-grid (V2G) and bidirectional charging pilots are expanding, allowing EVs to feed energy back to the grid or provide grid-balancing services during peak demand. Regulators and utilities are increasingly integrating these capabilities into pilots and future market designs.\n\n- Policy momentum and battery recycling/second-life use are shaping the future EV landscape: many regions plan ICE bans in the 2030s, incentives continue to support adoption, and new rules target recycled content and second-life battery storage, boosting domestic supply chains and reducing waste.', pydantic=None, json_dict=None, agent='Research Specialist', output_format=<OutputFormat.RAW: 'raw'>, messages=[{'role': 'system', 'content': 'You are Research Specialist. You are an expert at finding relevant and factual data\nYour personal goal is: Research interesting thing about The future of Eliectrical Vehicles'}, {'role': 'user', 'content': '\nCurrent Task: Find 3-5 recent and interesting facts about The future of Eliectrical Vehicles\n\nThis is the expected criteria for your final answer: A bullet list of 3-5 facts\nyou MUST return the actual complete content as the final answer, not a summary.\n\nProvide your complete response:'}, {'role': 'assistant', 'content': '- Battery costs near $100 per kWh by the mid-2020s, driving price parity with many internal combustion vehicles and lowering total cost of ownership for most buyers. This trend is accelerating broader EV adoption across segments.\n\n- Lithium iron phosphate (LFP) chemistries are becoming mainstream for affordable EVs due to lower cost and better durability, reducing reliance on nickel and cobalt. Many brands now offer LFP variants for standard-range models, while higher-end versions continue to use nickel-rich chemistries for longer range.\n\n- 800V architectures with ultra-fast charging (often 350 kW and above) are becoming common in new long-range EVs, enabling substantial recharges in minutes and making highway travel quicker and more convenient. This ...
# ╭──────────────────────────────────────────────── Tracing Status ─────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Info: Tracing is disabled.                                                                                     │
# │                                                                                                                 │
# │  To enable tracing, do any one of these:                                                                        │
# │  • Set tracing=True in your Crew/Flow code                                                                      │
# │  • Set CREWAI_TRACING_ENABLED=true in your project's .env file                                                  │
# │  • Run: crewai traces enable                                                                                    │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
